# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Fayllar bilan ishlash

# %%
df = pd.read_excel(r"c:\Users\User\projects\MohirDev\praktikum_datasets-main\uzbekistan.xlsx", index_col = 0, names=["hudud", "maydon", "aholi"])
df
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
pd.read_csv(r"c:\Users\User\projects\MohirDev\praktikum_datasets-main\automobile_data.csv", index_col="index")
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %%
df.to_csv("newuzb.csv")

# %%
obj = df.maydon
obj
# Out:
# hudud
# Andijon viloyati                   4200
# Buxoro viloyati                   39400
# Fargʻona viloyati                  6800
# Jizzax viloyati                   20500
# Xorazm viloyati                    6300
# Namangan viloyati                  7900
# Navoiy viloyati                  110800
# Qashqadaryo viloyati              28400
# Qoraqalpogʻiston Respublikasi    160000
# Samarqand viloyati                16400
# Sirdaryo viloyati                  5100
# Surxondaryo viloyati              20800
# Toshkent viloyati                 15300
# Name: maydon, dtype: int64

# %%
obj.to_csv("uzmaydon.csv")

# %%
pd.read_csv("uzmaydon.csv", index_col=0)
# Out:
#                                maydon
# hudud
# Andijon viloyati                 4200
# Buxoro viloyati                 39400
# Fargʻona viloyati                6800
# Jizzax viloyati                 20500
# Xorazm viloyati                  6300
# Namangan viloyati                7900
# Navoiy viloyati                110800
# Qashqadaryo viloyati            28400
# Qoraqalpogʻiston Respublikasi  160000
# Samarqand viloyati              16400
# Sirdaryo viloyati                5100
# Surxondaryo viloyati            20800
# Toshkent viloyati               15300

# %%
df2 = pd.read_csv(r"c:\Users\User\projects\MohirDev\praktikum_datasets-main\automobile_data.csv", index_col="index")
df2
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %%
df2.to_excel("newscars.xlsx", index = False) # indexslarni saqlamadi

# %%
df2.to_excel("newscars.xlsx", index = False, columns=["company", "body-style", "price"]) # ustunlarni tanlab saqladi

# %% [markdown]
# ## HDF5 formati

# %%
hdobj = pd.HDFStore("data.h5") # ochish

# %%
df
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
df2
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %%
hdobj.put("uzdata", df) #df qo'shish

# %%
hdobj.put("cardata", df2)

# %%
hdobj.keys()
# Out:
# ['/cardata', '/uzdata']

# %%
hdobj['uzdata']
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
hdobj['cardata']
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %%
hdobj.close() # yopish

# %%
data = pd.read_hdf("data.h5", key="uzdata") # df ga olish
data
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
data.to_hdf("data1.h5", key="uzdata")

# %% [markdown]
# ## Veb-sahifalardan oʻqish

# %%
tashkent = pd.read_html("https://en.wikipedia.org/wiki/Tashkent")

# %%
len(tashkent)
# Out:
# 18

# %%
tashkent[0]
# Out:
#                          Tashkent  Тошкент / Toshkent  \
# 0                                        Capital city
# 1                                            Tashkent
# 2   Clockwise from top: Skyline of Tashkent, Kukel...
# 3                                            FlagSeal
# 4                             Nickname: Tosh (A rock)
# 5   Motto(s): Kuch Adolatdadir ("Strength is in Ju...
# 6                  Location of Tashkent in Uzbekistan
# 7                                                 NaN
# 8                            TashkentTashkentTashkent
# 9   Coordinates: 41°18′40″N 69°16′47″E﻿ / ﻿41.3111...
# 10                                            Country
# 11                                            Settled
# 12                                          Divisions
# 13                                         Government
# 14                                             • Type
# 15                                            • Hakim
# ...

# %%
tashkent[10]
# Out:
#     Nr       District  Population (2021)[4]  Area (km2)[67][66]  \
# 0    1       Bektemir                 31400               17.83
# 1    2      Chilanzar                260700               29.94
# 2    3      Yashnobod                258800               33.70
# 3    4        Mirobod                142800               17.10
# 4    5  Mirzo Ulugbek                285000               35.15
# 5    6        Sergeli                105700               37.36
# 6    7   Shayxontoxur                348300               29.70
# 7    8        Olmazor                377100               34.50
# 8    9        Uchtepa                278200               24.00
# 9   10     Yakkasaray                121600               14.60
# 10  11      Yunusabad                352000               40.60
# 11  12     Yangihayot                132800               44.20
#
#     Density (area/km2)  Map
# 0                 1761  NaN
# 1                 8707  NaN
# 2                 7680  NaN
# ...

# %% [markdown]
# ## JSON va APIʼdan oʻqish

# %%
import requests
r = requests.get("https://openlibrary.org/subjects/python.json?published_in=2020-2024")

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'key': '/subjects/python',
#  'name': 'python',
#  'subject_type': 'subject',
#  'work_count': 24,
#  'works': [{'key': '/works/OL16976951W',
#    'title': 'Think Python',
#    'edition_count': 11,
#    'cover_id': 7363360,
#    'cover_edition_key': 'OL25763659M',
#    'subject': ['Computer programming',
#     'Software architecture',
#     'Python (Computer program language)',
#     'COMPUTERS / Programming Languages / C#',
#     'COMPUTERS / Programming Languages / Pascal',
#     'COMPUTERS / Programming Languages / Java',
#     'Computer',
#     'Programming Languages',
#     'General',
#     'Python',
#     'Bioinformatics',
#     'Games',
#     'Com051360',
#     'Cs.cmp_sc.prog_lang'],
#    'ia_collection': ['additional_collections',
#     'folkscanomy',
#     'folkscanomy_computer',
#     'folkscanomy_computer_inbox',
#     'inlibrary',
#     'internetarchivebooks',
#     'printdisabled'],
#    'lendinglibrary': False,
#    'printdisabled': True,
# ...

# %%
r.json()['works']
# Out:
# [{'key': '/works/OL16976951W',
#   'title': 'Think Python',
#   'edition_count': 11,
#   'cover_id': 7363360,
#   'cover_edition_key': 'OL25763659M',
#   'subject': ['Computer programming',
#    'Software architecture',
#    'Python (Computer program language)',
#    'COMPUTERS / Programming Languages / C#',
#    'COMPUTERS / Programming Languages / Pascal',
#    'COMPUTERS / Programming Languages / Java',
#    'Computer',
#    'Programming Languages',
#    'General',
#    'Python',
#    'Bioinformatics',
#    'Games',
#    'Com051360',
#    'Cs.cmp_sc.prog_lang'],
#   'ia_collection': ['additional_collections',
#    'folkscanomy',
#    'folkscanomy_computer',
#    'folkscanomy_computer_inbox',
#    'inlibrary',
#    'internetarchivebooks',
#    'printdisabled'],
#   'lendinglibrary': False,
#   'printdisabled': True,
#   'lending_edition': 'OL26455778M',
#   'lending_identifier': '2015ThinkPython',
#   'authors': [{'key': '/authors/OL6815485A', 'name': 'Allen B. Downey'},
# ...

# %%
pd.DataFrame(r.json())
# Out:
#                  key    name subject_type  work_count  \
# 0   /subjects/python  python      subject          24
# 1   /subjects/python  python      subject          24
# 2   /subjects/python  python      subject          24
# 3   /subjects/python  python      subject          24
# 4   /subjects/python  python      subject          24
# 5   /subjects/python  python      subject          24
# 6   /subjects/python  python      subject          24
# 7   /subjects/python  python      subject          24
# 8   /subjects/python  python      subject          24
# 9   /subjects/python  python      subject          24
# 10  /subjects/python  python      subject          24
# 11  /subjects/python  python      subject          24
#
#                                                 works
# 0   {'key': '/works/OL16976951W', 'title': 'Think ...
# 1   {'key': '/works/OL21349037W', 'title': 'Introd...
# 2   {'key': '/works/OL15664278W', 'title': 'Head F...
# ...

# %%
pd.DataFrame(r.json()['works']) # key berib ochadi
# Out:
#                    key                                              title  \
# 0   /works/OL16976951W                                       Think Python
# 1   /works/OL21349037W  Introduction to Python for Science and Enginee...
# 2   /works/OL15664278W                                  Head First Python
# 3   /works/OL17422847W                           Python For Data Analysis
# 4    /works/OL6045694W                               Python in a Nutshell
# 5   /works/OL21703042W                               Tour of Data Science
# 6   /works/OL19548251W                                Python for Everyone
# 7   /works/OL19932156W                                      Fluent Python
# 8   /works/OL25777002W                                Pandas for Everyone
# 9   /works/OL19547142W                   Mastering Python Design Patterns
# 10  /works/OL21245028W                                   Bite-Size Python
# 11  /works/OL25347363W                      Survival Analysis with Python
#
# ...

# %%
r.json().keys()
# Out:
# dict_keys(['key', 'name', 'subject_type', 'work_count', 'works'])

# %% [markdown]
# ### https://github.com/public-apis/public-apis
# #### API lar ro'yxati

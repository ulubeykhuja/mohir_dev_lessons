# %% [markdown]
# <a href="https://colab.research.google.com/github/ulubeykhuja/mohir_dev_lessons/blob/main/multiindex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3-1: Multindex

# %%
import pandas as pd
import numpy as np

# %%
# Odatiy index
data = pd.Series(np.random.randn(9),
                 index=['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'])
data
# Out:
# a    0.591717
# a    1.634179
# a   -0.129671
# b    0.737380
# b    1.015188
# c   -1.006569
# c   -0.790284
# d   -0.219074
# d   -0.265465
# dtype: float64

# %%
# Ierarxik index
data1 = pd.Series(np.random.randn(9),
                  index = [['a','a','a','b','b','c','c','d','d'],
                   [1,2,3,1,3,1,2,2,3]])
data1
# Out:
# a  1    0.851836
#    2   -0.934595
#    3   -1.087016
# b  1    0.081037
#    3   -1.459007
# c  1    0.210807
#    2   -0.135571
# d  2    0.204625
#    3    0.161536
# dtype: float64

# %%
print(data.index)
print(data1.index)
# Out:
# Index(['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'], dtype='object')
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('d', 2),
#             ('d', 3)],
#            )

# %%
data1.loc[:,2]
# Out:
# a   -0.934595
# c   -0.135571
# d    0.204625
# dtype: float64

# %%
data1
# Out:
# a  1    0.851836
#    2   -0.934595
#    3   -1.087016
# b  1    0.081037
#    3   -1.459007
# c  1    0.210807
#    2   -0.135571
# d  2    0.204625
#    3    0.161536
# dtype: float64

# %% [markdown]
# unstack()

# %%
data1 = data1.unstack()

# %%
data1
# Out:
#           1         2         3
# a  0.851836 -0.934595 -1.087016
# b  0.081037       NaN -1.459007
# c  0.210807 -0.135571       NaN
# d       NaN  0.204625  0.161536

# %%
data1.stack()
# Out:
# a  1    0.851836
#    2   -0.934595
#    3   -1.087016
# b  1    0.081037
#    3   -1.459007
# c  1    0.210807
#    2   -0.135571
# d  2    0.204625
#    3    0.161536
# dtype: float64

# %% [markdown]
# Maʼlumotlar toʻplami ustida iyerarxik indekslash

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# Cloning into 'Practicum_Datasets'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 60 (delta 17), reused 16 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 20.24 MiB | 5.18 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# Updating files: 100% (13/13), done.

# %%
df = pd.read_csv("/content/Practicum_Datasets/world_cities_air_water_quality.csv")
df
# Out:
#                   City                 "Region"                    "Country"  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#        "AirQuality"   "WaterPollution"
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3963 entries, 0 to 3962
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               3963 non-null   object
#  1    "Region"          3963 non-null   object
#  2    "Country"         3963 non-null   object
#  3    "AirQuality"      3963 non-null   float64
#  4    "WaterPollution"  3963 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 154.9+ KB

# %%
df.columns
# Out:
# Index(['City', ' "Region"', ' "Country"', ' "AirQuality"',
#        ' "WaterPollution"'],
#       dtype='object')

# %%
coluns = ['City', 'Region', 'Country', 'AirQuality',
       'WaterPollution']
df.columns = coluns

# %%
df
# Out:
#                   City                   Region                      Country  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#       AirQuality  WaterPollution
# ...

# %%
# qushtinoqlarni oldik
df.Region = df.Region.map(lambda x: x.replace('"',''))
df.Country = df.Country.map(lambda x: x.replace('"',''))
df
# Out:
#                   City                 Region                    Country  \
# 0        New York City               New York   United States of America
# 1     Washington, D.C.   District of Columbia   United States of America
# 2        San Francisco             California   United States of America
# 3               Berlin                                           Germany
# 4          Los Angeles             California   United States of America
# ...                ...                    ...                        ...
# 3958             Yanbu        Medina Province               Saudi Arabia
# 3959           Cordoba              Andalusia                      Spain
# 3960               Vic              Catalonia                      Spain
# 3961           Segovia       Castile and Leon                      Spain
# 3962       Zamora city       Castile and Leon                      Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
df_to_csv = df.to_csv('updated_data.csv', index=False)

# %%
df.Country = df.Country.map(lambda x: x.strip())
df.Region = df.Region.map(lambda x: x.strip())
df
# Out:
#                   City                Region                   Country  \
# 0        New York City              New York  United States of America
# 1     Washington, D.C.  District of Columbia  United States of America
# 2        San Francisco            California  United States of America
# 3               Berlin                                         Germany
# 4          Los Angeles            California  United States of America
# ...                ...                   ...                       ...
# 3958             Yanbu       Medina Province              Saudi Arabia
# 3959           Cordoba             Andalusia                     Spain
# 3960               Vic             Catalonia                     Spain
# 3961           Segovia      Castile and Leon                     Spain
# 3962       Zamora city      Castile and Leon                     Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
df[df.Country == 'Germany']
# Out:
#                         City                  Region  Country  AirQuality  \
# 3                     Berlin                          Germany   62.364130
# 28                   Cologne  North Rhine-Westphalia  Germany   60.714286
# 40                      Bonn  North Rhine-Westphalia  Germany   82.812500
# 52                 Heilbronn       Baden-Wurttemberg  Germany   80.000000
# 76                    Aachen  North Rhine-Westphalia  Germany   70.454545
# ...                      ...                     ...      ...         ...
# 2693             Bad Waldsee       Baden-Wurttemberg  Germany  100.000000
# 2714  Weilheim in Oberbayern                 Bavaria  Germany  100.000000
# 2727                  Buckow             Brandenburg  Germany   87.500000
# 3942                  Erfurt               Thuringia  Germany   85.000000
# 3943  Garmisch-Partenkirchen                 Bavaria  Germany  100.000000
#
#       WaterPollution
# 3          28.612717
# 28         27.777778
# ...

# %%
df[df.Country == 'Uzbekistan']
# Out:
#         City Region     Country  AirQuality  WaterPollution
# 21  Tashkent         Uzbekistan   56.451613       49.166667

# %%
# pivot_table orqa miltiindex
df1 = df.set_index(['Country', 'City'])
df1
# Out:
#                                                          Region  AirQuality  \
# Country                  City
# United States of America New York City                 New York   46.816038
#                          Washington, D.C.  District of Columbia   66.129032
#                          San Francisco               California   60.514019
# Germany                  Berlin                                   62.364130
# United States of America Los Angeles                 California   36.621622
# ...                                                         ...         ...
# Saudi Arabia             Yanbu                  Medina Province    0.000000
# Spain                    Cordoba                      Andalusia   85.714286
#                          Vic                          Catalonia  100.000000
#                          Segovia               Castile and Leon  100.000000
#                          Zamora city           Castile and Leon  100.000000
#
# ...

# %%
df1.loc['Germany']
# Out:
#                                         Region  AirQuality  WaterPollution
# City
# Berlin                                           62.364130       28.612717
# Cologne                 North Rhine-Westphalia   60.714286       27.777778
# Bonn                    North Rhine-Westphalia   82.812500       22.500000
# Heilbronn                    Baden-Wurttemberg   80.000000        0.000000
# Aachen                  North Rhine-Westphalia   70.454545       17.857143
# ...                                        ...         ...             ...
# Bad Waldsee                  Baden-Wurttemberg  100.000000       50.000000
# Weilheim in Oberbayern                 Bavaria  100.000000       50.000000
# Buckow                             Brandenburg   87.500000       50.000000
# Erfurt                               Thuringia   85.000000       50.000000
# Garmisch-Partenkirchen                 Bavaria  100.000000       50.000000
#
# [124 rows x 3 columns]

# %%
df2 = df1.copy()
df2
# Out:
#                                                          Region  AirQuality  \
# Country                  City
# United States of America New York City                 New York   46.816038
#                          Washington, D.C.  District of Columbia   66.129032
#                          San Francisco               California   60.514019
# Germany                  Berlin                                   62.364130
# United States of America Los Angeles                 California   36.621622
# ...                                                         ...         ...
# Saudi Arabia             Yanbu                  Medina Province    0.000000
# Spain                    Cordoba                      Andalusia   85.714286
#                          Vic                          Catalonia  100.000000
#                          Segovia               Castile and Leon  100.000000
#                          Zamora city           Castile and Leon  100.000000
#
# ...

# %%
df2['AirPollition'] = 100 - df2['AirQuality']
df2
# Out:
#                                                          Region  AirQuality  \
# Country                  City
# United States of America New York City                 New York   46.816038
#                          Washington, D.C.  District of Columbia   66.129032
#                          San Francisco               California   60.514019
# Germany                  Berlin                                   62.364130
# United States of America Los Angeles                 California   36.621622
# ...                                                         ...         ...
# Saudi Arabia             Yanbu                  Medina Province    0.000000
# Spain                    Cordoba                      Andalusia   85.714286
#                          Vic                          Catalonia  100.000000
#                          Segovia               Castile and Leon  100.000000
#                          Zamora city           Castile and Leon  100.000000
#
# ...

# %%
df2['WaterQuality'] = 100-df2['WaterPollution']
df2
# Out:
#                                                          Region  AirQuality  \
# Country                  City
# United States of America New York City                 New York   46.816038
#                          Washington, D.C.  District of Columbia   66.129032
#                          San Francisco               California   60.514019
# Germany                  Berlin                                   62.364130
# United States of America Los Angeles                 California   36.621622
# ...                                                         ...         ...
# Saudi Arabia             Yanbu                  Medina Province    0.000000
# Spain                    Cordoba                      Andalusia   85.714286
#                          Vic                          Catalonia  100.000000
#                          Segovia               Castile and Leon  100.000000
#                          Zamora city           Castile and Leon  100.000000
#
# ...

# %%
df2.drop(columns=['Region'], inplace=True)
df2
# Out:
#                                            AirQuality  WaterPollution  \
# Country                  City
# United States of America New York City      46.816038       49.504950
#                          Washington, D.C.   66.129032       49.107143
#                          San Francisco      60.514019       43.000000
# Germany                  Berlin             62.364130       28.612717
# United States of America Los Angeles        36.621622       61.299435
# ...                                               ...             ...
# Saudi Arabia             Yanbu               0.000000       50.000000
# Spain                    Cordoba            85.714286        8.333333
#                          Vic               100.000000        0.000000
#                          Segovia           100.000000        0.000000
#                          Zamora city       100.000000       50.000000
#
#                                            AirPollition  WaterQuality
# ...

# %%
df3 = pd.DataFrame(df2.values, index=df2.index, columns=[['AIR', 'AIR', 'WATER', 'WATER'], ['AirQuality', 'AirPollition', 'WaterQuality',  'WaterPollution']])
df3
# Out:
#                                                   AIR               \
#                                            AirQuality AirPollition
# Country                  City
# United States of America New York City      46.816038    49.504950
#                          Washington, D.C.   66.129032    49.107143
#                          San Francisco      60.514019    43.000000
# Germany                  Berlin             62.364130    28.612717
# United States of America Los Angeles        36.621622    61.299435
# ...                                               ...          ...
# Saudi Arabia             Yanbu               0.000000    50.000000
# Spain                    Cordoba            85.714286     8.333333
#                          Vic               100.000000     0.000000
#                          Segovia           100.000000     0.000000
#                          Zamora city       100.000000    50.000000
#
#                                                  WATER
# ...

# %%
df3.WATER
# Out:
#                                            WaterQuality  WaterPollution
# Country                  City
# United States of America New York City        53.183962       50.495050
#                          Washington, D.C.     33.870968       50.892857
#                          San Francisco        39.485981       57.000000
# Germany                  Berlin               37.635870       71.387283
# United States of America Los Angeles          63.378378       38.700565
# ...                                                 ...             ...
# Saudi Arabia             Yanbu               100.000000       50.000000
# Spain                    Cordoba              14.285714       91.666667
#                          Vic                   0.000000      100.000000
#                          Segovia               0.000000      100.000000
#                          Zamora city           0.000000       50.000000
#
# [3963 rows x 2 columns]

# %%
df3.columns.set_names  = ['Object', 'Info']
df3
# Out:
#                                                   AIR               \
#                                            AirQuality AirPollition
# Country                  City
# United States of America New York City      46.816038    49.504950
#                          Washington, D.C.   66.129032    49.107143
#                          San Francisco      60.514019    43.000000
# Germany                  Berlin             62.364130    28.612717
# United States of America Los Angeles        36.621622    61.299435
# ...                                               ...          ...
# Saudi Arabia             Yanbu               0.000000    50.000000
# Spain                    Cordoba            85.714286     8.333333
#                          Vic               100.000000     0.000000
#                          Segovia           100.000000     0.000000
#                          Zamora city       100.000000    50.000000
#
#                                                  WATER
# ...

# %% [markdown]
# **.swaplevel(), sort_index() – iyerarxik indeksli maʼlumotlarda indekslar oʻrnini almashtirish**

# %%
df3.swaplevel('Country', 'City') # index o'rnini almashtiramiz
# Out:
#                                                   AIR               \
#                                            AirQuality AirPollition
# City             Country
# New York City    United States of America   46.816038    49.504950
# Washington, D.C. United States of America   66.129032    49.107143
# San Francisco    United States of America   60.514019    43.000000
# Berlin           Germany                    62.364130    28.612717
# Los Angeles      United States of America   36.621622    61.299435
# ...                                               ...          ...
# Yanbu            Saudi Arabia                0.000000    50.000000
# Cordoba          Spain                      85.714286     8.333333
# Vic              Spain                     100.000000     0.000000
# Segovia          Spain                     100.000000     0.000000
# Zamora city      Spain                     100.000000    50.000000
#
#                                                  WATER
# ...

# %%
# Out:
#                                                   AIR               \
#                                            AirQuality AirPollition
# Country                  City
# United States of America New York City      46.816038    49.504950
#                          Washington, D.C.   66.129032    49.107143
#                          San Francisco      60.514019    43.000000
# Germany                  Berlin             62.364130    28.612717
# United States of America Los Angeles        36.621622    61.299435
# ...                                               ...          ...
# Saudi Arabia             Yanbu               0.000000    50.000000
# Spain                    Cordoba            85.714286     8.333333
#                          Vic               100.000000     0.000000
#                          Segovia           100.000000     0.000000
#                          Zamora city       100.000000    50.000000
#
#                                                  WATER
# ...

# %%
df3.sort_index(level=0, ascending=False) # indexlarni tartiblaymiz
# Out:
#                              AIR                     WATER
#                       AirQuality AirPollition WaterQuality WaterPollution
# Country     City
# Zimbabwe    Masvingo   25.000000    62.500000    75.000000      37.500000
#             Harare     38.461538    87.500000    61.538462      12.500000
#             Bulawayo   67.857143    71.428571    32.142857      28.571429
#             Bindura    50.000000    75.000000    50.000000      25.000000
# Zambia      Mansa      75.000000    25.000000    25.000000      75.000000
# ...                          ...          ...          ...            ...
# Afghanistan Kandahar    0.000000    75.000000   100.000000      25.000000
#             Kabul      18.421053    81.060606    81.578947      18.939394
#             Herat      43.750000    31.250000    56.250000      68.750000
#             Farah     100.000000     0.000000     0.000000     100.000000
#             Andkhoy    50.000000    50.000000    50.000000      50.000000
#
# ...

# %% [markdown]
# havola: https://jovian.ai/mansurbek-comchemai/3-3-1-hierarchical-indexing/v/1

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 5-MODUL. Machine Learning.
#
# ### Linear Regression

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/housing_LR.csv', index_col=0)
df.head(10)
# Out:
#         district  rooms  size  level  max_levels    price
# 0   Юнусабадский      3  57.0      4           4  52000.0
# 1  Яккасарайский      2  52.0      4           5  56000.0
# 2   Чиланзарский      2  42.0      4           4  37000.0
# 3   Чиланзарский      3  65.0      1           4  49500.0
# 4   Чиланзарский      3  70.0      3           5  55000.0
# 5   Чиланзарский      1  28.0      1           4  25500.0
# 6   Чиланзарский      1  30.0      2           4  21200.0
# 7  Яккасарайский      2  32.0      5           5  20000.0
# 8    Учтепинский      2  51.0      3           4  26200.0
# 9   Чиланзарский      1  30.0      1           4  22200.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['rooms'].plot(kind='hist', bins=20, title='rooms')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['size'].plot(kind='hist', bins=20, title='size')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['level'].plot(kind='hist', bins=20, title='level')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('district').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='index', y='rooms', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='rooms', y='size', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='size', y='level', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='level', y='max_levels', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['rooms']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('district')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='district', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('rooms')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['size']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('district')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='district', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('size')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['level']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('district')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='district', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('level')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['max_levels']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('district')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='district', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('max_levels')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['rooms'].plot(kind='line', figsize=(8, 4), title='rooms')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['size'].plot(kind='line', figsize=(8, 4), title='size')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['level'].plot(kind='line', figsize=(8, 4), title='level')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['district'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='index', y='district', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['district'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='rooms', y='district', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['district'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='size', y='district', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['district'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='level', y='district', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# # Ustunlar ta'rifi
# - `location` - sotilayotgan uy manzili
# - `district` - uy joylashgan tuman
# - `rooms` - xonalar soni
# - `size` - uy maydoni (kv.m)
# - `level` - uy

# %%
df['district'].value_counts()
# Out:
# district
# Чиланзарский         1616
# Мирзо-Улугбекский    1342
# Учтепинский           872
# Юнусабадский          847
# Мирабадский           717
# Яккасарайский         628
# Яшнободский           456
# Шайхантахурский       356
# Олмазорский           262
# Сергелийский          159
# Янгихаётский           15
# Бектемирский            8
# Name: count, dtype: int64

# %% [markdown]
# **Darsimiz uchun Chilonzor tumanidagi uylarning narxini bashorat qilib ko'ramiz**

# %%
housing = df[df.district=='Чиланзарский']
housing.head()
# Out:
#        district  rooms  size  level  max_levels    price
# 2  Чиланзарский      2  42.0      4           4  37000.0
# 3  Чиланзарский      3  65.0      1           4  49500.0
# 4  Чиланзарский      3  70.0      3           5  55000.0
# 5  Чиланзарский      1  28.0      1           4  25500.0
# 6  Чиланзарский      1  30.0      2           4  21200.0

# %%
X = housing['size'].to_numpy()
X
# Out:
# array([42., 65., 70., ..., 32., 70., 30.])

# %%
y = housing['price'].to_numpy()
y
# Out:
# array([37000., 49500., 55000., ..., 28000., 49800., 22914.])

# %% [markdown]
# **Narx va uy maydoni o'rtasida chiziqli bog'liqlik bor ekanini tekshirib ko'ramiz.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=housing, x='size', y='price')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=housing, x='size', y='price', line_kws={"color": "red"})
plt.show()

# %% [markdown]
# ## 1-Vazifa
# Sizning vazifangiz yuqoridagi `X` va `y` o'zgaruvchilardan quyidagi formuladan foydalangan xolda $\theta_0$ va $\theta_1$ koeffisientlarni hisoblash.
#
# ![Imgur](https://i.imgur.com/zZoXZxI.png)
#
# Bu yerda $\tilde{x}$ - `X` ustun uchun o'rtracha qiymat,  $\tilde{y}$ - `y` ustun uchun o'rtracha qiymat

# %%
import numpy as np

Xmean = np.mean(X)
ymean = np.mean(y)

# %%
theta1 = sum((X-Xmean)*(y-ymean))/sum((X-Xmean)**2)
print(f"{theta1=}")
# Out:
# theta1=np.float64(740.0264822713287)

# %%
theta0 = ymean - theta1*Xmean
print(f"{theta0=}")
# Out:
# theta0=np.float64(-195.94911352690542)

# %% [markdown]
# ## 2-Vazifa
# `X` dan bir nechta tasodifiy qiymatlarni ajratib oling va ularga mos keluvchi `y` ni yuqoridagi koeffisientlar yordamida hisoblab ko'ring.
#
# ![Imgur](https://i.imgur.com/iT5tffj.png)

# %%
x_test = housing.sample(10, random_state=42)['size'].to_numpy()
print(f"{x_test=}")
y_test = housing.sample(10, random_state=42)['price'].to_numpy()
print(f"{y_test=}")
# Out:
# x_test=array([54., 42., 36., 60., 48., 68., 38., 65., 52., 44.])
# y_test=array([37500., 26500., 25500., 39000., 32500., 34500., 22700., 47000.,
#        37900., 36000.])

# %%
y_predict = theta0 + theta1*x_test
print(f"{y_predict=}")
# Out:
# y_predict=array([39765.48092912, 30885.16314187, 26445.00424824, 44205.63982275,
#        35325.3220355 , 50125.85168092, 27925.05721278, 47905.77223411,
#        38285.42796458, 32365.21610641])

# %% [markdown]
# ## 3-Vazifa
#
# Hisoblangan va asl qiymtlar o'rtasidagi RMSE (root mean square error), MAE (mean absolute error) hisoblang.
#
# ![Imgur](https://i.imgur.com/GJH9CGy.png)
#
# ![Imgur](https://i.imgur.com/aXL9iWa.png)

# %%
# MAE
MAE = np.sum(np.absolute(y_predict-y_test))/len(y_test)
print(f"{MAE=}")
# Out:
# MAE=np.float64(4140.35031634715)

# %%
# RMSE
RMSE = np.sqrt(np.sum((y_predict-y_test)**2)/len(y_test))
print(f"{RMSE=}")
# Out:
# RMSE=np.float64(5882.051673173715)
